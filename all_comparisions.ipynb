# %% [markdown]
# # Assessment the algorithms that solve multi-armed bandit problem

# %% [markdown]
# ## All algorithms were brought from Richard Sutton's RL book

# %%
from tests import epsilon_greedy
from tests import nonstationary
from tests import UCB_vs_eps_greedy
from tests import optimistic
from tests import gradient_bandits

# %% [markdown]
# ## Greed vs $\epsilon$-greedy

# %%
epsilon_greedy.main()

# %% [markdown]
# ## Nonstationary case

# %%
nonstationary.main()

# %% [markdown]
# ## Upper-Confidence-Bound Action Selection vs Greedy

# %%
UCB_vs_eps_greedy.main()
# Out:
# C:\Users\mchau\source\rl_practice\multi-armed_bandit\src\strategies.py:47: RuntimeWarning: divide by zero encountered in true_divide
#   return self.values + self.c * (np.log(self.time) / number_of_actions) ** 0.5

# %% [markdown]
# ## Using Optimistic Initial Values

# %%
optimistic.main()

# %% [markdown]
# ## Gradient Bandits

# %%
gradient_bandits.main()
